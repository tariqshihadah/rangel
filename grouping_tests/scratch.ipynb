# %%
from base import Rangel
import common, selection, modify, utility
from rangel import RangeCollection
import numpy as np
import pandas as pd
import scipy.sparse as sparse
import geopandas as gpd
import linref as lr
import warnings

# %%
df_linear_1 = pd.DataFrame(index=[7, 6, 9, 4, 3, 2, 0, 1], data={
    'route': ['Main St', 'Main St', 'Main St', '1st Ave', '1st Ave', '2nd Ave', '2nd Ave', 'Sycamore School Rd'],
    'beg': [0.0, 0.5, 1.1, 10.0, 12.0, 13.0, 13.1, 1.8],
    'end': [0.4, 1.1, 3.0, 12.0, 13.0, 13.1, 14.0, 3.0],
    'volume': [100, 200, 100, 400, 500, 150, 200, 800],
})
#df_linear_1 = pd.concat([df_linear_1] * 100, ignore_index=True)#.sort_values(['route', 'beg'])
df_linear_2 = pd.DataFrame({
    'route': ['Main St', 'Main St', '1st Ave', '2nd Ave', '2nd Ave', 'Sycamore School Rd'],
    'beg': [0.0, 1.0, 10.0, 13.0, 13.1, 2.2],
    'end': [1.0, 2.0, 12.0, 13.0, 14.0, 2.8],
    'class': ['A', 'B', 'A', 'A', 'B', 'A'],
})
#df_linear_2 = pd.concat([df_linear_2] * 100, ignore_index=True)#.sort_values(['route', 'beg'])

# %%
rng1 = Rangel(index=df_linear_1.index, groups=df_linear_1.route, begs=df_linear_1.beg, ends=df_linear_1.end, closed='left_mod')
rng2 = Rangel(index=df_linear_2.index, groups=df_linear_2.route, begs=df_linear_2.beg, ends=df_linear_2.end, closed='left_mod')
rng3 = Rangel(index=df_linear_1.index, groups=df_linear_1.route, locs=df_linear_1.beg)

# %%
rc1 = RangeCollection(begs=df_linear_1.beg, ends=df_linear_1.end, closed='left_mod')
rc2 = RangeCollection(begs=df_linear_2.beg, ends=df_linear_2.end, closed='left_mod')

# %%
ec1 = lr.EventsCollection(df_linear_1, 'route', 'beg', 'end')
ec2 = lr.EventsCollection(df_linear_2, 'route', 'beg', 'end')

# %%
modify.concatenate([rng1, rng2], ignore_index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 modify.concatenate([rng1, rng2], ignore_index=False)
#
# File ~/code/rangel/grouping_tests/modify.py:124, in concatenate(rngs, ignore_index, closed)
#     121     index = np.concatenate([rng.index for rng in rngs])
#     123 # Return concatenated events
# --> 124 return rngs[0].from_similar(
#     125     index=index,
#     126     groups=groups,
#     127     locs=locs,
#     128     begs=begs,
#     129     ends=ends,
#     130     closed=closed if closed is not None else rngs[0].closed
#     131 )
#
# File ~/code/rangel/grouping_tests/base.py:46, in Rangel.from_similar(self, index, groups, locs, begs, ends, **kwargs)
#      40 kwargs = {
#      41     'closed': self.closed,
#      42     'dtype': self._dtype,
#      43     **kwargs
#      44 }
#      45 # Create new instance
# ---> 46 return self.__class__(
#      47     index=index, groups=groups, locs=locs, begs=begs, ends=ends, **kwargs)
#
# File ~/code/rangel/grouping_tests/base.py:27, in Rangel.__init__(self, index, groups, locs, begs, ends, closed, dtype, copy, force_monotonic)
#      14 def __init__(
#      15         self,
#      16         index=None,
#    (...)
#      25     ):
#      26     # Validate inputs
# ---> 27     self._validate_data(index, groups, locs, begs, ends, dtype=dtype, copy=copy)
#      28     self.set_closed(closed, inplace=True)
#      29     self._dtype = dtype
#
# File ~/code/rangel/grouping_tests/base.py:337, in Rangel._validate_data(self, index, groups, locs, begs, ends, dtype, copy)
#     335 # Validate index and groups
#     336 if not index is None:
# --> 337     index = self._validate_index(index)
#     338     data_arrays['index'] = index
#     339 if not groups is None:
#
# File ~/code/rangel/grouping_tests/base.py:273, in Rangel._validate_index(self, index)
#     271     # Check that all indices are unique
#     272     if len(np.unique(index)) < len(index):
# --> 273         raise ValueError(
#     274             "All input indices must be unique.")
#     275 return index
#
# ValueError: All input indices must be unique.

# %%
rng2
# Out:
# 0, group(           Main St) [ 0.000,  1.000)
# 1, group(           Main St) [ 1.000,  2.000]
# 2, group(           1st Ave) [10.000, 12.000]
# 3, group(           2nd Ave) [13.000, 13.000]
# 4, group(           2nd Ave) [13.100, 14.000]
# 5, group(Sycamore School Rd) [ 2.200,  2.800]
# Rangel(6 grouped, monotonic linear events, closed=left_mod)

# %%
rng1
# Out:
# 7, group(           Main St) [ 0.000,  0.400]
# 6, group(           Main St) [ 0.500,  1.100)
# 9, group(           Main St) [ 1.100,  3.000]
# 4, group(           1st Ave) [10.000, 12.000)
# 3, group(           1st Ave) [12.000, 13.000]
# 2, group(           2nd Ave) [13.000, 13.100)
# 0, group(           2nd Ave) [13.100, 14.000]
# 1, group(Sycamore School Rd) [ 1.800,  3.000]
# Rangel(8 grouped, monotonic linear events, closed=left_mod)
