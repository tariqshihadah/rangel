# %%
from base import Rangel
from rangel import RangeCollection
import numpy as np
import pandas as pd
import geopandas as gpd

# %%
df_linear_1 = pd.DataFrame({
    'route': ['Main St', 'Main St', 'Main St', '1st Ave', '1st Ave', '2nd Ave', '2nd Ave', 'Sycamore School Rd'],
    'beg': [0.0, 0.5, 1.1, 10.0, 12.0, 13.0, 13.1, 2.0],
    'end': [0.4, 1.1, 2.0, 12.0, 13.0, 13.1, 14.0, 3.0],
    'volume': [100, 200, 100, 400, 500, 150, 200, 800],
})
df_linear_2 = pd.DataFrame({
    'route': ['Main St', 'Main St', '1st Ave', '2nd Ave', '2nd Ave', 'Sycamore School Rd'],
    'beg': [0.0, 1.0, 10.0, 13.0, 13.1, 2.2],
    'end': [1.0, 2.0, 12.0, 13.0, 14.0, 2.5],
    'class': ['A', 'B', 'A', 'A', 'B', 'A'],
})

# %%
df_linear_1.lrs = Rangel(index=df_linear_1.index, groups=df_linear_1.route, begs=df_linear_1.beg, ends=df_linear_1.end, closed='left_mod')
df_linear_2.lrs = Rangel(index=df_linear_2.index, groups=df_linear_2.route, begs=df_linear_2.beg, ends=df_linear_2.end, closed='left_mod')

# %%
df_linear_1.lrs.consecutive_strings(), np.unique(df_linear_1.lrs.consecutive_strings(), return_index=True)
# Out:
# (array([0, 1, 1, 2, 2, 3, 3, 4]),
#  (array([0, 1, 2, 3, 4]), array([0, 1, 3, 5, 7])))

# %%
df_linear_1.lrs.dissolve(return_index=True)
# Out:
# (0, group(           Main St) [ 0.000,  0.400]
#  1, group(           Main St) [ 0.500,  2.000]
#  2, group(           1st Ave) [10.000, 13.000]
#  3, group(           2nd Ave) [13.000, 14.000]
#  4, group(Sycamore School Rd) [ 2.000,  3.000]
#  Rangel(5 grouped linear monotonic events, closed=left_mod),
#  [array([0]), array([1, 2]), array([3, 4]), array([5, 6]), array([7])])

# %%
df_linear_1.lrs
# Out:
# 0, group(           Main St) [ 0.000,  0.400]
# 1, group(           Main St) [ 0.500,  1.100)
# 2, group(           Main St) [ 1.100,  2.000]
# 3, group(           1st Ave) [10.000, 12.000)
# 4, group(           1st Ave) [12.000, 13.000]
# 5, group(           2nd Ave) [13.000, 13.100)
# 6, group(           2nd Ave) [13.100, 14.000]
# 7, group(Sycamore School Rd) [ 2.000,  3.000]
# Rangel(8 grouped linear monotonic events, closed=left_mod)

# %%
rng_pt1 = Rangel(locs=[0, 4, 6, 9, 3, 13])
rng_pt2 = Rangel(locs=[1, 4, 9])
rng_ln1 = Rangel(begs=[0, 3, 8, 12, 14], ends=[3, 5, 12, 13, 20], closed='left')
rng_ln2 = Rangel(begs=[-2, 0, 8, 14], ends=[0, 5, 9, 13], closed='right_mod')

# %%
rc_pt1 = RangeCollection(begs=[0, 4, 6, 9, 3, 13])
rc_pt2 = RangeCollection(begs=[1, 4, 9])
rc_ln1 = RangeCollection(begs=[0, 3, 8, 12, 14], ends=[3, 5, 12, 13, 20], closed='left')
rc_ln2 = RangeCollection(begs=[-2, 0, 8, 14], ends=[0, 5, 9, 13], closed='right_mod')

# %%
n = 10000
begs = np.random.randint(0, n, n)
ends = begs + np.random.randint(1, 10, n)
adj = int(n / 1.2)
rng1 = Rangel(begs=begs, ends=ends, closed='left_mod')
rng2 = Rangel(begs=begs + adj, ends=ends + adj, closed='left_mod')
rc1 = RangeCollection(begs=begs, ends=ends, closed='left_mod')
rc2 = RangeCollection(begs=begs + adj, ends=ends + adj, closed='left_mod')

# %%
# %%timeit
rng1.intersecting(rng2, enforce_edges=True)
# Out:
# 763 ms ± 12.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
rc1.intersecting(rc2)
# Out:
# 964 ms ± 80.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
